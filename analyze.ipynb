# %%
import data_reader
import matplotlib.pyplot as plt
import plotter

dr = data_reader.DataReader()

band_timeline = dr.get_actual_bands()
single_band = band_timeline[0]

plotter.plot_band(single_band)

# %%
plt.imshow(band_timeline)
plt.xlabel("Band")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')
